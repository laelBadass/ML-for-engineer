# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("salary.csv")

# %%
df
# Out:
#      year  salary
# 0     5.0   90000
# 1     3.0   65000
# 2    15.0  150000
# 3     7.0   60000
# 4    20.0  200000
# ..    ...     ...
# 359  20.0  200000
# 360   3.0   50000
# 361   4.0   55000
# 362  14.0  140000
# 363   1.0   35000
#
# [364 rows x 2 columns]

# %%
# %matplotlib inline
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.scatter(df.year,df.salary,color='green',marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.salary)
# Out:
# LinearRegression()

# %%
reg.predict([[8]])
# Out:
# C:\Users\ella\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([86210.05464923])

# %%
reg.coef_
# Out:
# array([7281.71640854])

# %%
reg.intercept_
# Out:
# 27956.32338092303

# %%
d = pd.read_csv("salary_to_predict.csv")

# %%
p = reg.predict(d)

# %%
d['salary'] = p

# %%
d.to_csv("predicted_salary.csv")

# %%
# %matplotlib inline
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.scatter(df.year,df.salary,color='red',marker='+')
